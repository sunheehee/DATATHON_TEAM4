# %% [markdown]
# # **TCN 모델을 이용한 환율 예측**
# - feature : 통계적으로 유의미한 변수
# - 선택법
#   - LASSO
#   - Feature Importance (RF기반)
#   - Permutation Importance (순열 중요도)

# %%
# %%capture
# !pip install koreanize-matplotlib
import koreanize_matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import linregress
from sklearn.preprocessing import MinMaxScaler
import random
import tensorflow as tf
import os

def set_seed(seed=30):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['PYTHONHASHSEED'] = '30'
    os.environ['TF_DETERMINISTIC_OPS'] = '1'      # TF 2.8+ 에서 결정론 연산 강제
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'   # CuDNN 결정론 모드 (구버전)
    os.environ['CUDA_VISIBLE_DEVICES'] = ''      # GPU 대신 CPU 사용 → 완전 재현성

set_seed(30)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/LikeLion/DataTone/exchange_final.csv")

df.head()
# Out:
#    Unnamed: 0        TIME   원/달러환율  한국 장기 시장 금리  미국 장기 시장 금리  중국 장기 시장 금리  \
# 0           0  2000-01-01  1130.32          NaN         6.66          NaN
# 1           1  2000-02-01  1129.29          NaN         6.52          NaN
# 2           2  2000-03-01  1115.75          NaN         6.26          NaN
# 3           3  2000-04-01  1110.01          NaN         5.99          NaN
# 4           4  2000-05-01  1121.37          NaN         6.44          NaN
#
#    한국 단기 시장 금리  미국 단기 시장 금리  중국 단기 시장 금리  전체 수출 총액  ...  한국 중앙정부 부채 비율  \
# 0         7.28         5.95         2.72  12162425  ...            NaN
# 1         7.13         6.01         2.73  12676042  ...            NaN
# 2         7.00         6.14         2.64  14429703  ...            NaN
# 3         7.06         6.28         2.64  13522040  ...            NaN
# 4         7.14         6.71         2.57  14636755  ...            NaN
#
#    미국 중앙정부 부채 비율  한국 10년 채권수익률  미국 10년 채권수익률  한국 인플레이션율  미국 인플레이션율  인플레이션 격차  \
# 0      33.267642           NaN           NaN        NaN        NaN       NaN
# 1      34.865592           NaN           NaN        NaN        NaN       NaN
# 2      36.463543           NaN           NaN        NaN        NaN       NaN
# 3      38.061493           NaN           NaN        NaN        NaN       NaN
# 4      39.659444           NaN           NaN        NaN        NaN       NaN
#
#            실질GDP  실질GDP성장률    vix
# 0  883159.302102       NaN  24.95
# 1  876860.243167       NaN  23.37
# 2  870598.143103       NaN  24.11
# 3  864372.677584       NaN  26.20
# 4  858183.526068       NaN  23.65
#
# [5 rows x 74 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     300 non-null    int64
#  1   TIME           300 non-null    object
#  2   원/달러환율         300 non-null    float64
#  3   한국 장기 시장 금리    291 non-null    float64
#  4   미국 장기 시장 금리    300 non-null    float64
#  5   중국 장기 시장 금리    132 non-null    float64
#  6   한국 단기 시장 금리    300 non-null    float64
#  7   미국 단기 시장 금리    299 non-null    float64
#  8   중국 단기 시장 금리    299 non-null    float64
#  9   전체 수출 총액       300 non-null    int64
#  10  미국 수출 총액       300 non-null    int64
#  11  중국 수출 총액       300 non-null    int64
#  12  전체 수입 총액       300 non-null    int64
#  13  미국 수입 총액       300 non-null    int64
#  14  중국 수입 총액       300 non-null    int64
#  15  소득 교역 조건 지수    300 non-null    float64
#  16  해외 직접 투자 금액    300 non-null    int64
#  17  경제 심리 지수       264 non-null    float64
#  18  한국 기준 금리       300 non-null    float64
#  19  미국 기준 금리       300 non-null    float64
#  20  중국 기준 금리       300 non-null    float64
#  21  한국 소비자 물가지수    300 non-null    float64
#  22  미국 소비자 물가지수    300 non-null    float64
#  23  중국 소비자 물가지수    300 non-null    float64
#  24  한국 외환 보유액      240 non-null    float64
#  25  미국 외환 보유액      280 non-null    float64
#  26  중국 외환 보유액      115 non-null    float64
#  27  한국 산업 생산 지수    300 non-null    float64
#  28  미국 산업 생산 지수    300 non-null    float64
#  29  한국 실업률         300 non-null    float64
#  30  미국 실업률         300 non-null    float64
#  31  한국 주가지수        300 non-null    float64
#  32  미국 주가지수        300 non-null    float64
#  33  중국 주가지수        300 non-null    float64
#  34  WTI 유가         300 non-null    float64
#  35  두바이 유가         300 non-null    float64
#  36  Brent 유가       300 non-null    float64
#  37  천연가스 가격        300 non-null    float64
#  38  유연탄 가격         300 non-null    float64
#  39  철광석 가격         300 non-null    float64
#  40  구리 가격          300 non-null    float64
#  41  알루미늄 가격        300 non-null    float64
#  42  니켈 가격          300 non-null    float64
#  43  아연 가격          300 non-null    float64
#  44  금 가격           300 non-null    float64
#  45  대두 가격          300 non-null    float64
#  46  옥수수 가격         300 non-null    float64
#  47  소맥 가격          300 non-null    float64
#  48  원당 가격          300 non-null    float64
#  49  원면 가격          300 non-null    float64
#  50  외국인 투자 금액      298 non-null    float64
#  51  한국 경상수지        298 non-null    float64
#  52  미국 경상수지        298 non-null    float64
#  53  중국 경상수지        238 non-null    float64
#  54  한국 상품수지        298 non-null    float64
#  55  미국 상품수지        298 non-null    float64
#  56  중국 상품수지        238 non-null    float64
#  57  한국 경제성장률       298 non-null    float64
#  58  미국 경제성장률       298 non-null    float64
#  59  중국 경제성장률       166 non-null    float64
#  60  한국 GDP         289 non-null    float64
#  61  미국 GDP         289 non-null    float64
#  62  중국 GDP         289 non-null    float64
#  63  한국 GDP 디플레이터   289 non-null    float64
#  64  한국 중앙정부 부채 비율  133 non-null    float64
#  65  미국 중앙정부 부채 비율  277 non-null    float64
#  66  한국 10년 채권수익률   290 non-null    float64
#  67  미국 10년 채권수익률   290 non-null    float64
#  68  한국 인플레이션율      288 non-null    float64
#  69  미국 인플레이션율      288 non-null    float64
#  70  인플레이션 격차       288 non-null    float64
#  71  실질GDP          289 non-null    float64
#  72  실질GDP성장률       288 non-null    float64
#  73  vix            300 non-null    float64
# dtypes: float64(65), int64(8), object(1)
# memory usage: 173.6+ KB

# %%
m2 = pd.read_csv('/content/drive/MyDrive/LikeLion/DataTone/M2_2000_2024.CSV', encoding='cp949')

# 'Jan-00' → datetime으로 변환 (월 초 날짜 기준)
m2['TIME'] = pd.to_datetime(m2['TIME'], format='%Y-%m')

# 확인
print(m2.head())
# Out:
#         TIME        M2  증가율
# 0 2000-01-01  674.7231 -0.8
# 1 2000-02-01  677.6103  0.4
# 2 2000-03-01  685.3970  1.1
# 3 2000-04-01  689.5531  0.6
# 4 2000-05-01  688.6894 -0.1

# %%
df['TIME'] = pd.to_datetime(df['TIME'])

# 병합
df_merged = pd.merge(df, m2, on='TIME', how='left')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     300 non-null    int64
#  1   TIME           300 non-null    datetime64[ns]
#  2   원/달러환율         300 non-null    float64
#  3   한국 장기 시장 금리    291 non-null    float64
#  4   미국 장기 시장 금리    300 non-null    float64
#  5   중국 장기 시장 금리    132 non-null    float64
#  6   한국 단기 시장 금리    300 non-null    float64
#  7   미국 단기 시장 금리    299 non-null    float64
#  8   중국 단기 시장 금리    299 non-null    float64
#  9   전체 수출 총액       300 non-null    int64
#  10  미국 수출 총액       300 non-null    int64
#  11  중국 수출 총액       300 non-null    int64
#  12  전체 수입 총액       300 non-null    int64
#  13  미국 수입 총액       300 non-null    int64
#  14  중국 수입 총액       300 non-null    int64
#  15  소득 교역 조건 지수    300 non-null    float64
#  16  해외 직접 투자 금액    300 non-null    int64
#  17  경제 심리 지수       264 non-null    float64
#  18  한국 기준 금리       300 non-null    float64
#  19  미국 기준 금리       300 non-null    float64
#  20  중국 기준 금리       300 non-null    float64
#  21  한국 소비자 물가지수    300 non-null    float64
#  22  미국 소비자 물가지수    300 non-null    float64
#  23  중국 소비자 물가지수    300 non-null    float64
#  24  한국 외환 보유액      240 non-null    float64
#  25  미국 외환 보유액      280 non-null    float64
#  26  중국 외환 보유액      115 non-null    float64
#  27  한국 산업 생산 지수    300 non-null    float64
#  28  미국 산업 생산 지수    300 non-null    float64
#  29  한국 실업률         300 non-null    float64
#  30  미국 실업률         300 non-null    float64
#  31  한국 주가지수        300 non-null    float64
#  32  미국 주가지수        300 non-null    float64
#  33  중국 주가지수        300 non-null    float64
#  34  WTI 유가         300 non-null    float64
#  35  두바이 유가         300 non-null    float64
#  36  Brent 유가       300 non-null    float64
#  37  천연가스 가격        300 non-null    float64
#  38  유연탄 가격         300 non-null    float64
#  39  철광석 가격         300 non-null    float64
#  40  구리 가격          300 non-null    float64
#  41  알루미늄 가격        300 non-null    float64
#  42  니켈 가격          300 non-null    float64
#  43  아연 가격          300 non-null    float64
#  44  금 가격           300 non-null    float64
#  45  대두 가격          300 non-null    float64
#  46  옥수수 가격         300 non-null    float64
#  47  소맥 가격          300 non-null    float64
#  48  원당 가격          300 non-null    float64
#  49  원면 가격          300 non-null    float64
#  50  외국인 투자 금액      298 non-null    float64
#  51  한국 경상수지        298 non-null    float64
#  52  미국 경상수지        298 non-null    float64
#  53  중국 경상수지        238 non-null    float64
#  54  한국 상품수지        298 non-null    float64
#  55  미국 상품수지        298 non-null    float64
#  56  중국 상품수지        238 non-null    float64
#  57  한국 경제성장률       298 non-null    float64
#  58  미국 경제성장률       298 non-null    float64
#  59  중국 경제성장률       166 non-null    float64
#  60  한국 GDP         289 non-null    float64
#  61  미국 GDP         289 non-null    float64
#  62  중국 GDP         289 non-null    float64
#  63  한국 GDP 디플레이터   289 non-null    float64
#  64  한국 중앙정부 부채 비율  133 non-null    float64
#  65  미국 중앙정부 부채 비율  277 non-null    float64
#  66  한국 10년 채권수익률   290 non-null    float64
#  67  미국 10년 채권수익률   290 non-null    float64
#  68  한국 인플레이션율      288 non-null    float64
#  69  미국 인플레이션율      288 non-null    float64
#  70  인플레이션 격차       288 non-null    float64
#  71  실질GDP          289 non-null    float64
#  72  실질GDP성장률       288 non-null    float64
#  73  vix            300 non-null    float64
#  74  M2             300 non-null    float64
#  75  증가율            300 non-null    float64
# dtypes: datetime64[ns](1), float64(67), int64(8)
# memory usage: 178.3 KB

# %% [markdown]
# ## **유의미한 변수 (20개)**

# %%
# 변수 정의
features = ['경제 심리 지수', '한국 외환 보유액', 'vix', 'WTI 유가', '한국 실업률', '두바이 유가',
                        'Brent 유가', '천연가스 가격', '유연탄 가격', '미국 주가지수',
                        '한국 인플레이션율', '인플레이션 격차', '실질GDP성장률','M2',
                        '금 가격', '구리 가격', '아연 가격', '알루미늄 가격', '니켈 가격',
                        '외국인 투자 금액']

# %%
len(features)
# Out:
# 20

# %% [markdown]
# ## 타겟 설정

# %%
# 타겟 생성
target = df_merged['원/달러환율']

# %% [markdown]
# ## 결측치 처리
# - 선형 보간 (interpolate(method='linear'))
# - 순방향/역방향 채움 (ffill, bfill)

# %%
# 결측치 처리
df_filled = df_merged.interpolate(method='linear')
df_filled = df_filled.fillna(method='ffill').fillna(method='bfill')
# Out:
# <ipython-input-12-8ada04c1227d>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df_filled.fillna(method='ffill').fillna(method='bfill')

# %% [markdown]
# ## train/test 분할
# - 시계열 순서 유지한 80% / 20% 분할

# %%
# 전체 길이 기준으로 분할 비율 설정
total_len = len(df_filled)
split = int(total_len * 0.8)

# 시계열 순서 유지하여 분할
train_df = df_filled.iloc[:split]
test_df = df_filled.iloc[split:]

# %% [markdown]
# ## 정규화

# %%
# 정규화 - 훈련 데이터로만 스케일러 학습
scaler = MinMaxScaler()

# 훈련 데이터로 스케일러 학습 및 변환
train_scaled_array = scaler.fit_transform(train_df[features + ['원/달러환율']])
train_scaled = pd.DataFrame(train_scaled_array, columns=features + ['원/달러환율'])
train_scaled['TIME'] = train_df['TIME'].values  # 시간 정보 복원

# 테스트 데이터에 학습된 스케일러 적용
test_scaled_array = scaler.transform(test_df[features + ['원/달러환율']])
test_scaled = pd.DataFrame(test_scaled_array, columns=features + ['원/달러환율'])
test_scaled['TIME'] = test_df['TIME'].values  # 시간 정보 복원

# 입력(X), 타겟(y) 분리
X_train = train_scaled[features]
X_test = test_scaled[features]

y_train = train_scaled['원/달러환율']
y_test = test_scaled['원/달러환율']

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.4.26)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.5 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %% [markdown]
# ## **모델링**

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.4.26)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, LayerNormalization, Activation
from tensorflow.keras.layers import SpatialDropout1D, Add, Input, GlobalAveragePooling1D
from tensorflow.keras.models import Model
import keras_tuner as kt

# 시드 고정
np.random.seed(42)
tf.random.set_seed(42)


# TCN 블록 구현
def tcn_block(x, dilation_rate, nb_filters, kernel_size, dropout_rate=0.1):
    # Skip 연결을 위해 입력값 저장
    prev_x = x

    # 1D dilated causal convolution
    x = Conv1D(filters=nb_filters,
               kernel_size=kernel_size,
               dilation_rate=dilation_rate,
               padding='causal',
               activation=None)(x)

    # Layer Normalization & Activation & Dropout
    x = LayerNormalization()(x)
    x = Activation('relu')(x)
    x = SpatialDropout1D(dropout_rate)(x)

    # 두 번째 convolution
    x = Conv1D(filters=nb_filters,
               kernel_size=kernel_size,
               dilation_rate=dilation_rate,
               padding='causal',
               activation=None)(x)

    x = LayerNormalization()(x)
    x = Activation('relu')(x)
    x = SpatialDropout1D(dropout_rate)(x)

    # Skip 연결을 위한 1x1 conv
    if prev_x.shape[-1] != nb_filters:
        prev_x = Conv1D(nb_filters, kernel_size=1)(prev_x)

    # Skip 연결 추가
    x = Add()([x, prev_x])
    return x

# %%
# TCN 모델 생성 함수
def create_tcn_model(input_shape, nb_filters=64, kernel_size=3, nb_stacks=1, dilations=None, dropout_rate=0.1):
    if dilations is None:
        dilations = [1, 2, 4, 8, 16]

    input_layer = Input(shape=input_shape)
    x = input_layer

    # 초기 convolution
    x = Conv1D(filters=nb_filters, kernel_size=1, padding='causal')(x)

    # TCN 스택
    for _ in range(nb_stacks):
        for dilation in dilations:
            x = tcn_block(x, dilation, nb_filters, kernel_size, dropout_rate)

    # 출력층
    x = GlobalAveragePooling1D()(x)
    output_layer = Dense(1)(x)

    model = Model(inputs=input_layer, outputs=output_layer)
    return model

def build_tcn_model(hp):
    input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])
    input_layer = Input(shape=input_shape)
    x = Conv1D(filters=hp.Int("filters", 16, 128, step=16),
               kernel_size=1, padding='causal')(input_layer)

    for dilation in [1, 2, 4, 8, 16]:
        x = tcn_block(
            x,
            dilation_rate=dilation,
            nb_filters=hp.Int("filters", 16, 128, step=16),
            kernel_size=hp.Choice("kernel_size", [2, 3, 4]),
            dropout_rate=hp.Float("dropout", 0.1, 0.5, step=0.1)
        )

    x = GlobalAveragePooling1D()(x)
    output = Dense(1)(x)

    model = Model(inputs=input_layer, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mse'
    )
    return model


# 시계열 데이터를 지도학습 형태로 변환하는 함수
def create_sequences(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

# 데이터 준비 - 선택된 피처만 사용
X_train_selected = train_scaled[features]
X_test_selected = test_scaled[features]

# 시계열 데이터 준비 (time_steps 설정)
time_steps = 12

# 시퀀스 생성
X_train_seq, y_train_seq = create_sequences(X_train_selected.values, y_train.values, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test_selected.values, y_test.values, time_steps)

print(f"훈련 데이터 형태: {X_train_seq.shape}, {y_train_seq.shape}")
print(f"테스트 데이터 형태: {X_test_seq.shape}, {y_test_seq.shape}")
print(f"선택된 피처 개수: {len(features)}")
print(f"선택된 피처: {features}")
# Out:
# 훈련 데이터 형태: (228, 12, 20), (228,)
# 테스트 데이터 형태: (48, 12, 20), (48,)
# 선택된 피처 개수: 20
# 선택된 피처: ['경제 심리 지수', '한국 외환 보유액', 'vix', 'WTI 유가', '한국 실업률', '두바이 유가', 'Brent 유가', '천연가스 가격', '유연탄 가격', '미국 주가지수', '한국 인플레이션율', '인플레이션 격차', '실질GDP성장률', 'M2', '금 가격', '구리 가격', '아연 가격', '알루미늄 가격', '니켈 가격', '외국인 투자 금액']

# %% [markdown]
# ## **모델 생성**

# %%
# TCN 모델 생성 (최적 파라미터 적용)
input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])  # (time_steps, 선택된 피처 개수)
model = create_tcn_model(
    input_shape,
    nb_filters=64,
    kernel_size=2,
    nb_stacks=1,
    dilations=[1, 2, 4, 8, 16, 32],
    dropout_rate=0.1)

# 모델 컴파일
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse'
)

# 모델 요약
model.summary()

# 조기 종료 콜백
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

# 모델 체크포인트
model_checkpoint = ModelCheckpoint(
    filepath='best_tcn_model_selected_features.h5',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 12, 20)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 12, 64)    │      1,344 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 12, 64)    │      8,256 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 12, 64)    │        128 │ conv1d_1[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d   │ (None, 12, 64)    │          0 │ activation[0][0]  │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 12, 64)    │      8,256 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_2[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_1 │ (None, 12, 64)    │          0 │ activation_1[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 12, 64)    │          0 │ spatial_dropout1… │
# │                     │                   │            │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 12, 64)    │      8,256 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_3[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_2 │ (None, 12, 64)    │          0 │ activation_2[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 12, 64)    │      8,256 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_4[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_3 │ (None, 12, 64)    │          0 │ activation_3[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 12, 64)    │          0 │ spatial_dropout1… │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 12, 64)    │      8,256 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_5[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_4 │ (None, 12, 64)    │          0 │ activation_4[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 12, 64)    │      8,256 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_6[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_5 │ (None, 12, 64)    │          0 │ activation_5[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 12, 64)    │          0 │ spatial_dropout1… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 12, 64)    │      8,256 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_7[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_6 │ (None, 12, 64)    │          0 │ activation_6[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 12, 64)    │      8,256 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_8[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_7 │ (None, 12, 64)    │          0 │ activation_7[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 12, 64)    │          0 │ spatial_dropout1… │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 12, 64)    │      8,256 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_9[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_8 │ (None, 12, 64)    │          0 │ activation_8[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 12, 64)    │      8,256 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_10[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_9 │ (None, 12, 64)    │          0 │ activation_9[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 12, 64)    │          0 │ spatial_dropout1… │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 12, 64)    │      8,256 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_11[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 12, 64)    │          0 │ activation_10[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 12, 64)    │      8,256 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 12, 64)    │        128 │ conv1d_12[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 12, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_… │ (None, 12, 64)    │          0 │ activation_11[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 12, 64)    │          0 │ spatial_dropout1… │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ add_5[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │         65 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 102,017 (398.50 KB)
#  Trainable params: 102,017 (398.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tuner = kt.RandomSearch(
    build_tcn_model,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=1,
    directory='keras_tuner_dir',
    project_name='tcn_tuning'
)

tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=50,
    batch_size=32,
    callbacks=[EarlyStopping(patience=10)],
    verbose=1
)
# Out:
# Trial 10 Complete [00h 00m 22s]
# val_loss: 0.09714382141828537
#
# Best val_loss So Far: 0.013076957315206528
# Total elapsed time: 00h 05m 29s

# %% [markdown]
# ## **모델 학습**

# %%
# 최적 하이퍼파라미터 적용한 모델로 재학습
best_hps = tuner.get_best_hyperparameters(1)[0]
model = tuner.hypermodel.build(best_hps)

history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=300,
    batch_size=32,
    callbacks=[early_stopping, model_checkpoint],
    verbose=1
)
# Out:
# Epoch 1/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 134.0858
# Epoch 1: val_loss improved from inf to 0.08612, saving model to best_tcn_model_selected_features.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - loss: 125.1872 - val_loss: 0.0861
# Epoch 2/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.4744
# Epoch 2: val_loss did not improve from 0.08612
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.4975 - val_loss: 1.8217
# Epoch 3/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.1894
# Epoch 3: val_loss did not improve from 0.08612
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.2245 - val_loss: 1.0043
# Epoch 4/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6208
# Epoch 4: val_loss improved from 0.08612 to 0.03175, saving model to best_tcn_model_selected_features.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.6438 - val_loss: 0.0318
# Epoch 5/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5661
# Epoch 5: val_loss did not improve from 0.03175
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.5422 - val_loss: 0.6090
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3746
# Epoch 6: val_loss improved from 0.03175 to 0.01999, saving model to best_tcn_model_selected_features.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.3701 - val_loss: 0.0200
# Epoch 7/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2538
# Epoch 7: val_loss did not improve from 0.01999
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2563 - val_loss: 0.0329
# Epoch 8/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1792
# Epoch 8: val_loss improved from 0.01999 to 0.01228, saving model to best_tcn_model_selected_features.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1806 - val_loss: 0.0123
# Epoch 9/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1910
# Epoch 9: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1887 - val_loss: 0.0400
# Epoch 10/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1450
# Epoch 10: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.1452 - val_loss: 0.0518
# Epoch 11/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1544
# Epoch 11: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.1512 - val_loss: 0.0547
# Epoch 12/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1447
# Epoch 12: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.1401 - val_loss: 0.1241
# Epoch 13/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1258
# Epoch 13: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1270 - val_loss: 0.1061
# Epoch 14/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1312
# Epoch 14: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1295 - val_loss: 0.1106
# Epoch 15/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1219
# Epoch 15: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1226 - val_loss: 0.2157
# Epoch 16/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1229
# Epoch 16: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1211 - val_loss: 0.0893
# Epoch 17/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0918
# Epoch 17: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0930 - val_loss: 0.1293
# Epoch 18/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0889
# Epoch 18: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0873 - val_loss: 0.1513
# Epoch 19/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0846
# Epoch 19: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0839 - val_loss: 0.0684
# Epoch 20/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0786
# Epoch 20: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0792 - val_loss: 0.0979
# Epoch 21/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0757
# Epoch 21: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0756 - val_loss: 0.1315
# Epoch 22/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0812
# Epoch 22: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0802 - val_loss: 0.0823
# Epoch 23/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0645
# Epoch 23: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0667 - val_loss: 0.0525
# Epoch 24/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0692
# Epoch 24: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0695 - val_loss: 0.0803
# Epoch 25/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0514
# Epoch 25: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0526 - val_loss: 0.0476
# Epoch 26/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0595
# Epoch 26: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0595 - val_loss: 0.0577
# Epoch 27/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0520
# Epoch 27: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0518 - val_loss: 0.0312
# Epoch 28/300
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0363
# Epoch 28: val_loss did not improve from 0.01228
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0378 - val_loss: 0.0466
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %% [markdown]
# ## 선택법별 피처 중요도

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# 0) 기본 변수 리스트
features = [
    '경제 심리 지수', '한국 외환 보유액', 'vix', 'WTI 유가', '한국 실업률', '두바이 유가',
    'Brent 유가', '천연가스 가격', '유연탄 가격', '미국 주가지수',
    '한국 인플레이션율', '인플레이션 격차', '실질GDP성장률', 'M2',
    '금 가격', '구리 가격', '아연 가격', '알루미늄 가격', '니켈 가격',
    '외국인 투자 금액'
]

# 1) LassoCV 로 변수 중요도 (절대 계수) 계산
X_train_tab = train_scaled[features].values
y_train_tab = train_scaled['원/달러환율'].values

lasso = LassoCV(cv=5, random_state=42).fit(X_train_tab, y_train_tab)
lasso_coef = pd.Series(np.abs(lasso.coef_), index=features)
lasso_rank = lasso_coef.sort_values(ascending=False)

# 2) RandomForestRegressor 로 Feature Importance 계산
rf = RandomForestRegressor(n_estimators=200, random_state=42).fit(X_train_tab, y_train_tab)
rf_imp = pd.Series(rf.feature_importances_, index=features)
rf_rank = rf_imp.sort_values(ascending=False)

# 3) Permutation Importance (TCN) — 이전에 정의한 함수 사용
#    importances = permutation_importance_tcn(model, X_test_seq, y_test_seq, features)
#    names, scores = zip(*importances)
perm_rank = pd.Series(
    data=[score for _, score in importances],
    index=[name for name, _ in importances]
).sort_values(ascending=False)

# 4) 세 가지를 한 테이블로 합치기
df_imp = pd.DataFrame({
    'Lasso': lasso_rank,
    'RandomForest': rf_rank,
    'Permutation': perm_rank
})
# NaN 은 해당 방법에서 계산되지 않은 경우 (e.g. Permutation 은 순서가 약간 다를 수 있음)
df_imp = df_imp.fillna(0)

# 5) 상위 10개 변수 각 방법별로 출력
print("== Lasso Top 10 ==")
print(lasso_rank.head(10))
print("\n== RF Top 10 ==")
print(rf_rank.head(10))
print("\n== Permutation Top 10 ==")
print(perm_rank.head(10))

# 6) 시각화: 상위 10개만 골라 막대그래프
topN = 10
df_imp.head(topN).plot.barh(figsize=(8,6))
plt.xlabel("Importance (normalized or ΔRMSE)")
plt.title("Feature Importance Comparison")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0014594841674353543, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0017462839260449226, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001768256543376756, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0017275021709050042, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0016733674693666378, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0016175018175486056, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015627138962706066, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015097384885836007, tolerance: 0.0006085496286939899
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001059023702351114, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010705333684176699, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010504796078452117, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010244508547431197, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009967080221818803, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009682496289148412, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009590083976520614, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009330376781557792, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0008888983269892403, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0008587275905392877, tolerance: 0.0008389466253429557
#   model = cd_fast.enet_coordinate_descent_gram(
# == Lasso Top 10 ==
# M2           0.397467
# 인플레이션 격차     0.250972
# 니켈 가격        0.239494
# vix          0.236364
# 한국 외환 보유액    0.229296
# WTI 유가       0.164947
# 아연 가격        0.141507
# 천연가스 가격      0.131961
# 알루미늄 가격      0.124049
# 금 가격         0.078848
# dtype: float64
#
# == RF Top 10 ==
# 미국 주가지수     0.399362
# 천연가스 가격     0.168055
# 알루미늄 가격     0.091428
# M2          0.074974
# 니켈 가격       0.055308
# 경제 심리 지수    0.038186
# 아연 가격       0.035200
# vix         0.031451
# 인플레이션 격차    0.018185
# 실질GDP성장률    0.015786
# dtype: float64
#
# == Permutation Top 10 ==
# 인플레이션 격차     0.053052
# M2           0.019351
# 경제 심리 지수     0.015414
# 외국인 투자 금액    0.013803
# 금 가격         0.010705
# 미국 주가지수      0.009948
# 두바이 유가       0.006651
# Brent 유가     0.005696
# 유연탄 가격       0.005649
# 아연 가격        0.003343
# dtype: float64

# %% [markdown]
# ## 선택법(1) Permutation Importance

# %%
# ─── 여기에 삽입: Permutation Importance ───
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

def permutation_importance_tcn(model, X, y, feature_names, n_repeats=5):
    y_pred = model.predict(X).flatten()
    baseline = math.sqrt(mean_squared_error(y, y_pred))
    imps = []
    for i, name in enumerate(feature_names):
        rmses = []
        for _ in range(n_repeats):
            Xp = X.copy()
            Xp[:, :, i] = np.random.permutation(Xp[:, :, i])
            yp = model.predict(Xp).flatten()
            rmses.append(math.sqrt(mean_squared_error(y, yp)))
        imps.append((name, np.mean(rmses) - baseline))
    return sorted(imps, key=lambda x: x[1], reverse=True)

feature_names = features
importances = permutation_importance_tcn(model, X_test_seq, y_test_seq, feature_names)

names, scores = zip(*importances)
plt.figure(figsize=(8,6))
plt.barh(names[::-1], scores[::-1])
plt.xlabel('증가된 RMSE')
plt.title('TCN Permutation Importance')
plt.tight_layout()
plt.show()

top20 = [n for n,_ in importances[:20]]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# 1) Top Features 리스트 (이미 permutation importance로 정렬된 순서)
top_features = ['유연탄 가격', '한국 실업률', 'Brent 유가', 'M2', '니켈 가격', '실질GDP성장률', 'vix',
                '인플레이션 격차', '한국 외환 보유액', '금 가격', '아연 가격',
                '두바이 유가', '천연가스 가격', '구리 가격', '알루미늄 가격', '미국 주가지수',
                '경제 심리 지수', '외국인 투자 금액', '한국 인플레이션율', 'WTI 유가']
# 2) 평가용 함수 정의
def train_and_eval(feature_list, time_steps=12,
                   nb_filters=64, kernel_size=2, dilations=[1,2,4,8,16,32], dropout=0.1):
    # 2-1) 시퀀스 생성
    X_tr = train_scaled[feature_list].values
    X_te = test_scaled[feature_list].values
    y_tr = train_scaled['원/달러환율'].values
    y_te = test_scaled['원/달러환율'].values

    def make_sequences(X, y, ts):
        Xs, ys = [], []
        for i in range(len(X)-ts):
            Xs.append(X[i:i+ts])
            ys.append(y[i+ts])
        return np.array(Xs), np.array(ys)

    X_tr_seq, y_tr_seq = make_sequences(X_tr, y_tr, time_steps)
    X_te_seq, y_te_seq = make_sequences(X_te, y_te, time_steps)

    # 2-2) 모델 생성
    inp_shape = (time_steps, len(feature_list))
    model = create_tcn_model(inp_shape,
                             nb_filters=nb_filters,
                             kernel_size=kernel_size,
                             nb_stacks=1,
                             dilations=dilations,
                             dropout_rate=dropout)
    model.compile(optimizer=Adam(1e-3), loss='mse')

    # 2-3) 학습
    es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    cp = ModelCheckpoint('tmp.h5', monitor='val_loss', save_best_only=True, verbose=0)
    model.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_te_seq, y_te_seq),
        epochs=100, batch_size=32,
        callbacks=[es, cp],
        verbose=0
    )

    # 2-4) 예측·평가
    pred_tr = model.predict(X_tr_seq).flatten()
    pred_te = model.predict(X_te_seq).flatten()
    def metrics(y_true, y_pred):
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mae  = mean_absolute_error(y_true, y_pred)
        r2   = r2_score(y_true, y_pred)
        return rmse, mae, r2

    tr_rmse, tr_mae, tr_r2 = metrics(y_tr_seq, pred_tr)
    te_rmse, te_mae, te_r2 = metrics(y_te_seq, pred_te)

    return {
        'N_features': len(feature_list),
        'features': feature_list,
        'train_rmse': tr_rmse, 'train_mae': tr_mae, 'train_r2': tr_r2,
        'test_rmse': te_rmse,  'test_mae': te_mae,  'test_r2': te_r2,
    }

# 3) 여러 N에 대해 반복 실행
results = []
for N in [3, 5, 10, 15]:
    feats = top_features[:N]
    res = train_and_eval(feats, time_steps=12)
    results.append(res)

# 4) DataFrame으로 정리
df_results = pd.DataFrame(results)[[
    'N_features','test_rmse','test_mae','test_r2'
]]
print(df_results)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#    N_features  test_rmse  test_mae   test_r2
# 0           3   0.125085  0.097277  0.464944
# 1           5   0.189734  0.147527 -0.231058
# 2          10   0.257323  0.187707 -1.264353
# 3          15   0.201276  0.153821 -0.385391

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 1) feature 리스트 + 타겟 인덱스 정의 (scaler.fit_transform 시 사용한 순서와 동일해야 합니다)
feature_names = features + ['원/달러환율']
target_idx   = feature_names.index('원/달러환율')

# 2) 역변환 함수
def inverse_transform_sequence(y_scaled, scaler, target_idx):
    """
    y_scaled: (n_samples,) 정규화된 타겟 시퀀스
    scaler:   train_scaled.fit_transform 에 사용한 MinMaxScaler 객체
    target_idx: feature_names.index('원/달러환율')
    """
    # 모든 변수를 0으로 채운 더미 배열 생성
    dummy = np.zeros((len(y_scaled), len(feature_names)))
    # 타겟 열에만 스케일된 값 삽입
    dummy[:, target_idx] = y_scaled
    # 역변환
    inv = scaler.inverse_transform(dummy)
    # 다시 타겟 열만 꺼내기
    return inv[:, target_idx]

# 3) 예시: N별 성능 비교 루프에 아래를 추가
results_orig = []

for N in [3,5,10,15]:
    feats = top_features[:N]

    # 2-1) N개 피처로 X_train/X_test 재추출
    X_tr = train_scaled[feats].values
    X_te = test_scaled[feats].values
    y_tr = train_scaled['원/달러환율'].values
    y_te = test_scaled['원/달러환율'].values

    # 2-2) 시퀀스 생성
    X_tr_seq, y_tr_seq = create_sequences(X_tr, y_tr, time_steps=12)
    X_te_seq, y_te_seq = create_sequences(X_te, y_te, time_steps=12)

    # 2-3) 모델 정의 (input_shape=(12, N))
    inp_shape = (12, N)
    model = create_tcn_model(inp_shape,
                             nb_filters=64,
                             kernel_size=2,
                             dilations=[1,2,4,8,16,32],
                             dropout_rate=0.1)
    model.compile(optimizer=Adam(1e-3), loss='mse')

    # 2-4) 학습
    model.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_te_seq, y_te_seq),
        epochs=100, batch_size=32,
        callbacks=[early_stopping, model_checkpoint],
        verbose=0
    )

    # 2-5) 예측 및 역변환
    pred_te = model.predict(X_te_seq).flatten()
    y_true_orig = inverse_transform_sequence(y_te_seq, scaler, target_idx)
    y_pred_orig = inverse_transform_sequence(pred_te,   scaler, target_idx)

    # 2-6) 성능 계산
    rmse_o = np.sqrt(mean_squared_error(y_true_orig, y_pred_orig))
    mae_o  = mean_absolute_error   (y_true_orig, y_pred_orig)
    r2_o   = r2_score              (y_true_orig, y_pred_orig)

    results_orig.append({
        'N_features': N,
        'rmse_orig': rmse_o,
        'mae_orig': mae_o,
        'r2_orig': r2_o
    })

# 3) 결과 정리
df_orig = pd.DataFrame(results_orig)
print(df_orig)
# Out:
# Epoch 1: val_loss did not improve from 0.01228
#
# Epoch 2: val_loss did not improve from 0.01228
#
# Epoch 3: val_loss did not improve from 0.01228
#
# Epoch 4: val_loss did not improve from 0.01228
#
# Epoch 5: val_loss did not improve from 0.01228
#
# Epoch 6: val_loss improved from 0.01228 to 0.01189, saving model to best_tcn_model_selected_features.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: val_loss did not improve from 0.01189
#
# Epoch 8: val_loss did not improve from 0.01189
#
# Epoch 9: val_loss did not improve from 0.01189
#
# Epoch 10: val_loss did not improve from 0.01189
#
# Epoch 11: val_loss did not improve from 0.01189
#
# Epoch 12: val_loss did not improve from 0.01189
#
# Epoch 13: val_loss did not improve from 0.01189
#
# Epoch 14: val_loss did not improve from 0.01189
#
# Epoch 15: val_loss did not improve from 0.01189
#
# Epoch 16: val_loss did not improve from 0.01189
#
# Epoch 17: val_loss did not improve from 0.01189
#
# Epoch 18: val_loss did not improve from 0.01189
#
# Epoch 19: val_loss did not improve from 0.01189
#
# Epoch 20: val_loss did not improve from 0.01189
#
# Epoch 21: val_loss did not improve from 0.01189
#
# Epoch 22: val_loss did not improve from 0.01189
#
# Epoch 23: val_loss did not improve from 0.01189
#
# Epoch 24: val_loss did not improve from 0.01189
#
# Epoch 25: val_loss did not improve from 0.01189
#
# Epoch 26: val_loss did not improve from 0.01189
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
#
# Epoch 1: val_loss did not improve from 0.01189
#
# Epoch 2: val_loss did not improve from 0.01189
#
# Epoch 3: val_loss did not improve from 0.01189
#
# Epoch 4: val_loss did not improve from 0.01189
#
# Epoch 5: val_loss did not improve from 0.01189
#
# Epoch 6: val_loss did not improve from 0.01189
#
# Epoch 7: val_loss did not improve from 0.01189
#
# Epoch 8: val_loss did not improve from 0.01189
#
# Epoch 9: val_loss did not improve from 0.01189
#
# Epoch 10: val_loss did not improve from 0.01189
#
# Epoch 11: val_loss did not improve from 0.01189
#
# Epoch 12: val_loss did not improve from 0.01189
#
# Epoch 13: val_loss did not improve from 0.01189
#
# Epoch 14: val_loss did not improve from 0.01189
#
# Epoch 15: val_loss did not improve from 0.01189
#
# Epoch 16: val_loss did not improve from 0.01189
#
# Epoch 17: val_loss did not improve from 0.01189
#
# Epoch 18: val_loss did not improve from 0.01189
#
# Epoch 19: val_loss did not improve from 0.01189
#
# Epoch 20: val_loss did not improve from 0.01189
#
# Epoch 21: val_loss did not improve from 0.01189
#
# Epoch 22: val_loss did not improve from 0.01189
#
# Epoch 23: val_loss did not improve from 0.01189
#
# Epoch 24: val_loss did not improve from 0.01189
#
# Epoch 25: val_loss did not improve from 0.01189
#
# Epoch 26: val_loss did not improve from 0.01189
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 6.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cf6ca52fec0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# WARNING:tensorflow:6 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cf6ca52fec0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
#
# Epoch 1: val_loss did not improve from 0.01189
#
# Epoch 2: val_loss did not improve from 0.01189
#
# Epoch 3: val_loss did not improve from 0.01189
#
# Epoch 4: val_loss did not improve from 0.01189
#
# Epoch 5: val_loss did not improve from 0.01189
#
# Epoch 6: val_loss did not improve from 0.01189
#
# Epoch 7: val_loss did not improve from 0.01189
#
# Epoch 8: val_loss did not improve from 0.01189
#
# Epoch 9: val_loss did not improve from 0.01189
#
# Epoch 10: val_loss did not improve from 0.01189
#
# Epoch 11: val_loss did not improve from 0.01189
#
# Epoch 12: val_loss did not improve from 0.01189
#
# Epoch 13: val_loss did not improve from 0.01189
#
# Epoch 14: val_loss did not improve from 0.01189
#
# Epoch 15: val_loss did not improve from 0.01189
#
# Epoch 16: val_loss did not improve from 0.01189
#
# Epoch 17: val_loss did not improve from 0.01189
#
# Epoch 18: val_loss did not improve from 0.01189
#
# Epoch 19: val_loss did not improve from 0.01189
#
# Epoch 20: val_loss did not improve from 0.01189
#
# Epoch 21: val_loss did not improve from 0.01189
#
# Epoch 22: val_loss did not improve from 0.01189
#
# Epoch 23: val_loss did not improve from 0.01189
#
# Epoch 24: val_loss did not improve from 0.01189
#
# Epoch 25: val_loss did not improve from 0.01189
#
# Epoch 26: val_loss did not improve from 0.01189
#
# Epoch 27: val_loss did not improve from 0.01189
#
# Epoch 28: val_loss did not improve from 0.01189
#
# Epoch 29: val_loss did not improve from 0.01189
#
# Epoch 30: val_loss did not improve from 0.01189
#
# Epoch 31: val_loss did not improve from 0.01189
#
# Epoch 32: val_loss did not improve from 0.01189
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
#
# Epoch 1: val_loss did not improve from 0.01189
#
# Epoch 2: val_loss did not improve from 0.01189
#
# Epoch 3: val_loss did not improve from 0.01189
#
# Epoch 4: val_loss did not improve from 0.01189
#
# Epoch 5: val_loss did not improve from 0.01189
#
# Epoch 6: val_loss did not improve from 0.01189
#
# Epoch 7: val_loss did not improve from 0.01189
#
# Epoch 8: val_loss did not improve from 0.01189
#
# Epoch 9: val_loss did not improve from 0.01189
#
# Epoch 10: val_loss did not improve from 0.01189
#
# Epoch 11: val_loss did not improve from 0.01189
#
# Epoch 12: val_loss did not improve from 0.01189
#
# Epoch 13: val_loss did not improve from 0.01189
#
# Epoch 14: val_loss did not improve from 0.01189
#
# Epoch 15: val_loss did not improve from 0.01189
#
# Epoch 16: val_loss did not improve from 0.01189
#
# Epoch 17: val_loss did not improve from 0.01189
#
# Epoch 18: val_loss did not improve from 0.01189
#
# Epoch 19: val_loss did not improve from 0.01189
#
# Epoch 20: val_loss did not improve from 0.01189
#
# Epoch 21: val_loss did not improve from 0.01189
#
# Epoch 22: val_loss did not improve from 0.01189
#
# Epoch 23: val_loss did not improve from 0.01189
#
# Epoch 24: val_loss did not improve from 0.01189
#
# Epoch 25: val_loss did not improve from 0.01189
#
# Epoch 26: val_loss did not improve from 0.01189
#
# Epoch 27: val_loss did not improve from 0.01189
#
# Epoch 28: val_loss did not improve from 0.01189
#
# Epoch 29: val_loss did not improve from 0.01189
#
# Epoch 30: val_loss did not improve from 0.01189
#
# Epoch 31: val_loss did not improve from 0.01189
#
# Epoch 32: val_loss did not improve from 0.01189
#
# Epoch 33: val_loss did not improve from 0.01189
#
# Epoch 34: val_loss did not improve from 0.01189
#
# Epoch 35: val_loss did not improve from 0.01189
#
# Epoch 36: val_loss did not improve from 0.01189
#
# Epoch 37: val_loss did not improve from 0.01189
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
#    N_features  rmse_orig   mae_orig   r2_orig
# 0           3  58.728423  48.888813  0.593324
# 1           5  61.048558  44.019396  0.560557
# 2          10  81.148105  70.462089  0.223559
# 3          15  99.459725  79.284142 -0.166396

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K

# 1) Best 모델 재학습 (N=5)
best_N = 5
best_feats = top_features[:best_N]

# 시퀀스 재생성
X_tr = train_scaled[best_feats].values
y_tr = train_scaled['원/달러환율'].values
X_te = test_scaled[best_feats].values
y_te = test_scaled['원/달러환율'].values

X_tr_seq, y_tr_seq = create_sequences(X_tr, y_tr, time_steps=12)
X_te_seq, y_te_seq = create_sequences(X_te, y_te, time_steps=12)

# 모델 초기화 및 생성
K.clear_session()
model_best = create_tcn_model(
    input_shape=(12, best_N),
    nb_filters=64,
    kernel_size=2,
    dilations=[1,2,4,8,16,32],
    dropout_rate=0.1
)
model_best.compile(optimizer=Adam(1e-3), loss='mse')

# 학습 (history 저장)
history = model_best.fit(
    X_tr_seq, y_tr_seq,
    validation_data=(X_te_seq, y_te_seq),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping, model_checkpoint],
    verbose=1
)

# 2) Overfitting 그래프 (Train vs Validation Loss)
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('TCN Overfitting Check (N=5 Features)')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# 3) Actual vs Predicted 그래프
# 예측 후 역변환
pred_te_scaled = model_best.predict(X_te_seq).flatten()
y_true_orig  = inverse_transform_sequence(y_te_seq, scaler, target_idx)
y_pred_orig  = inverse_transform_sequence(pred_te_scaled, scaler, target_idx)

plt.figure(figsize=(10, 5))
plt.plot(y_true_orig, label='실제 환율')
plt.plot(y_pred_orig, '--', label='예측 환율')
plt.title('Actual vs Predicted (N=5 Features)')
plt.xlabel('Time Step')
plt.ylabel('원/달러 환율')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.7388
# Epoch 1: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - loss: 5.5687 - val_loss: 1.3641
# Epoch 2/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.9826
# Epoch 2: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 1.9451 - val_loss: 0.9929
# Epoch 3/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.7143
# Epoch 3: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.6423 - val_loss: 1.2873
# Epoch 4/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.9769
# Epoch 4: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.9373 - val_loss: 0.0928
# Epoch 5/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.6595
# Epoch 5: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.6647 - val_loss: 0.3103
# Epoch 6/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.6325
# Epoch 6: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.6316 - val_loss: 0.1071
# Epoch 7/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4415
# Epoch 7: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.4504 - val_loss: 0.0458
# Epoch 8/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4228
# Epoch 8: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4251 - val_loss: 0.1357
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4380
# Epoch 9: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.4374 - val_loss: 0.0420
# Epoch 10/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4211
# Epoch 10: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4150 - val_loss: 0.0250
# Epoch 11/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4407
# Epoch 11: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4345 - val_loss: 0.1795
# Epoch 12/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4575
# Epoch 12: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.4424 - val_loss: 0.0110
# Epoch 13/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3324
# Epoch 13: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3269 - val_loss: 0.0148
# Epoch 14/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2680
# Epoch 14: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2696 - val_loss: 0.0213
# Epoch 15/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2496
# Epoch 15: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.2493 - val_loss: 0.0284
# Epoch 16/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2639
# Epoch 16: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2617 - val_loss: 0.0655
# Epoch 17/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2106
# Epoch 17: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2157 - val_loss: 0.0188
# Epoch 18/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2424
# Epoch 18: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.2414 - val_loss: 0.0145
# Epoch 19/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2111
# Epoch 19: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2124 - val_loss: 0.0551
# Epoch 20/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2309
# Epoch 20: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2287 - val_loss: 0.0276
# Epoch 21/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1651
# Epoch 21: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1688 - val_loss: 0.0523
# Epoch 22/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2512
# Epoch 22: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2474 - val_loss: 0.0215
# Epoch 23/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1386
# Epoch 23: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1409 - val_loss: 0.0494
# Epoch 24/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1618
# Epoch 24: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1594 - val_loss: 0.0704
# Epoch 25/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1684
# Epoch 25: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1707 - val_loss: 0.0531
# Epoch 26/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1566
# Epoch 26: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.1604 - val_loss: 0.0433
# Epoch 27/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1807
# Epoch 27: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.1758 - val_loss: 0.0290
# Epoch 28/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1332
# Epoch 28: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.1353 - val_loss: 0.0411
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1567
# Epoch 29: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1566 - val_loss: 0.0311
# Epoch 30/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1567
# Epoch 30: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1529 - val_loss: 0.0832
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1541
# Epoch 31: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1531 - val_loss: 0.0351
# Epoch 32/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1181
# Epoch 32: val_loss did not improve from 0.00458
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1190 - val_loss: 0.1000
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 784ms/step

# %% [markdown]
# ## 선택법(2) LassoCV

# %%
from tensorflow.keras import backend as K

results = []

for N in range(1, 21):
    topN = list(lasso_rank.index[:N])

    # 1) N개 피처만 뽑아서 시계열 시퀀스 생성
    X_tr = train_scaled[topN].values
    y_tr = train_scaled['원/달러환율'].values
    X_te = test_scaled [topN].values
    y_te = test_scaled ['원/달러환율'].values

    def make_seq(X, y, time_steps=12):
        Xs, ys = [], []
        for i in range(len(X) - time_steps):
            Xs.append(X[i:i+time_steps])
            ys.append(y[i+time_steps])
        return np.array(Xs), np.array(ys)

    X_tr_seq, y_tr_seq = make_seq(X_tr, y_tr, time_steps=12)
    X_te_seq, y_te_seq = make_seq(X_te, y_te, time_steps=12)

    # ─── 여기부터 반드시 루프 안 ───
    K.clear_session()   # 이전 모델 그래프 초기화
    model_n = create_tcn_model(
        input_shape=(12, N),
        nb_filters=64,
        kernel_size=2,
        dilations=[1,2,4,8,16,32],
        dropout_rate=0.1
    )
    model_n.compile(optimizer=Adam(1e-3), loss='mse')

    es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    cp = ModelCheckpoint('tmp.h5', monitor='val_loss', save_best_only=True, verbose=0)

    model_n.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_te_seq, y_te_seq),
        epochs=100, batch_size=32,
        callbacks=[es, cp],
        verbose=0
    )
    # ─── 여기까지 ───

    # 2) 예측 및 역변환
    pred = model_n.predict(X_te_seq).flatten()
    y_true_orig = inverse_transform_sequence(y_te_seq, scaler, target_idx)
    y_pred_orig = inverse_transform_sequence(pred,     scaler, target_idx)

    # 3) 성능 계산
    rmse = np.sqrt(mean_squared_error(y_true_orig, y_pred_orig))
    mae  = mean_absolute_error   (y_true_orig, y_pred_orig)
    r2   = r2_score              (y_true_orig, y_pred_orig)

    results.append({
        'N_features': N,
        'RMSE (원화)': rmse,
        'MAE (원화)': mae,
        'R2': r2
    })

# 결과 정리
df_lasso_perf = pd.DataFrame(results).set_index('N_features')
print(df_lasso_perf)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 754ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 735ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 719ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 685ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
#              RMSE (원화)    MAE (원화)        R2
# N_features
# 1            84.276840   74.934339  0.162532
# 2            93.018179   72.505422 -0.020204
# 3           129.247545   90.472745 -0.969682
# 4           114.597747   92.500925 -0.548473
# 5            96.382853   79.342050 -0.095345
# 6            93.709523   85.995703 -0.035426
# 7           107.788812   82.880113 -0.369932
# 8            99.797967   83.945618 -0.174343
# 9            77.590209   65.132350  0.290152
# 10           70.822216   52.508793  0.408587
# 11          103.724234   88.024231 -0.268563
# 12          101.892373   87.315934 -0.224151
# 13          104.947882   90.353658 -0.298670
# 14          152.512777  110.044784 -1.742609
# 15          177.417732  129.834773 -2.711466
# 16          179.525828  161.268302 -2.800190
# 17           91.054925   78.296431  0.022406
# 18           73.713299   62.457119  0.359317
# 19           76.191647   58.357468  0.315511
# 20          175.040422  160.200567 -2.612669

# %% [markdown]
# ## 선택법(3) Feature Importance (RF 기반)

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

# 1) RF로 전체 피처 중요도 계산
features = [
    '경제 심리 지수', '한국 외환 보유액', 'vix', 'WTI 유가', '한국 실업률', '두바이 유가',
    'Brent 유가', '천연가스 가격', '유연탄 가격', '미국 주가지수',
    '한국 인플레이션율', '인플레이션 격차', '실질GDP성장률', 'M2',
    '금 가격', '구리 가격', '아연 가격', '알루미늄 가격', '니켈 가격',
    '외국인 투자 금액'
]
X_tab = train_scaled[features].values
y_tab = train_scaled['원/달러환율'].values

rf = RandomForestRegressor(n_estimators=200, random_state=42)
rf.fit(X_tab, y_tab)
rf_imp = pd.Series(rf.feature_importances_, index=features)
rf_rank = rf_imp.sort_values(ascending=False)

# 2) 성능 기록 리스트
results = []

# 3) Top N별 반복
for N in range(1, 21):
    topN = list(rf_rank.index[:N])

    # 시계열 시퀀스 생성 함수
    def make_seq(X, y, ts=12):
        Xs, ys = [], []
        for i in range(len(X) - ts):
            Xs.append(X[i:i+ts])
            ys.append(y[i+ts])
        return np.array(Xs), np.array(ys)

    # 데이터 준비
    X_tr = train_scaled[topN].values; y_tr = train_scaled['원/달러환율'].values
    X_te = test_scaled [topN].values; y_te = test_scaled ['원/달러환율'].values
    X_tr_seq, y_tr_seq = make_seq(X_tr, y_tr, ts=12)
    X_te_seq, y_te_seq = make_seq(X_te, y_te, ts=12)

    # 모델 새로 생성
    K.clear_session()
    model_n = create_tcn_model(
        input_shape=(12, N),
        nb_filters=64,
        kernel_size=2,
        dilations=[1,2,4,8,16,32],
        dropout_rate=0.1
    )
    model_n.compile(optimizer=Adam(1e-3), loss='mse')

    # 학습
    es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    cp = ModelCheckpoint('tmp.h5', monitor='val_loss', save_best_only=True, verbose=0)
    model_n.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_te_seq, y_te_seq),
        epochs=100, batch_size=32,
        callbacks=[es, cp],
        verbose=0
    )

    # 예측 & 역변환
    pred = model_n.predict(X_te_seq).flatten()
    y_true_orig = inverse_transform_sequence(y_te_seq, scaler, target_idx)
    y_pred_orig = inverse_transform_sequence(pred,     scaler, target_idx)

    # 성능 계산
    rmse = np.sqrt(mean_squared_error(y_true_orig, y_pred_orig))
    mae  = mean_absolute_error   (y_true_orig, y_pred_orig)
    r2   = r2_score              (y_true_orig, y_pred_orig)

    results.append({
        'N_features': N,
        'RMSE (원화)': rmse,
        'MAE (원화)': mae,
        'R2': r2
    })

# 4) 결과 DataFrame
df_rf_perf = pd.DataFrame(results).set_index('N_features')
print(df_rf_perf)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 986ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 953ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 728ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
#              RMSE (원화)    MAE (원화)        R2
# N_features
# 1            92.065174   77.202719  0.000593
# 2           104.415560   83.531252 -0.285529
# 3            88.950121   76.880666  0.067080
# 4            94.269441   78.540194 -0.047836
# 5           113.551726   91.288051 -0.520334
# 6            90.897717   73.490986  0.025779
# 7           114.630226   90.699383 -0.549351
# 8           110.771310   98.200917 -0.446792
# 9            85.330893   73.805429  0.141453
# 10          154.701720  135.182700 -1.821901
# 11          133.720355  119.023984 -1.108369
# 12           95.496497   70.930279 -0.075292
# 13          189.640955  174.648026 -3.240487
# 14          102.348684   83.606829 -0.235139
# 15           96.446930   83.558501 -0.096802
# 16           96.586658   81.761584 -0.099982
# 17          150.697294  136.197529 -1.677703
# 18          101.517385   84.229117 -0.215157
# 19           90.904251   77.815118  0.025639
# 20           82.452688   71.988993  0.198394
